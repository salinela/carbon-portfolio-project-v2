# %% [markdown]
# # Transaction

# %%
# TRANSACTION.CSV - deferred to feature engineering stage
# Key use: derive net_allowance_position per company per year
# Steps when needed:
#   1. Filter to EUA unit type only (check unitType_id values)
#   2. Filter to Internal + External transaction types only
#   3. Convert date to datetime
#   4. Link transferringAccount_id / acquiringAccount_id → bvd_id
#   5. Aggregate net position per company per year
#   6. Combine with surrender.csv for carbon_cost_pressure feature
